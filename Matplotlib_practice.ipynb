# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Basic Matplotlib command

plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('practice')
# Out:
# Text(0.5, 1.0, 'practice')

# %%
# creating multiple plots with canvas
# plt.subplot(nrows , ncols , plot_numbers)
plt.subplot(1,2,1)
plt.plot(x, y,'r--')
plt.subplot(1,2,2)
plt.plot(y, x,'g*-')

# %%
# matplotlib object oriented method

# %%
# create a empty canvas
fig = plt.figure()

# add set of axes to figure
axes = fig.add_axes([0.1,0.1,0.8,0.8])   # default values left, bottom, width, height (range 0 to 1) 
axes.plot(x,y,'b')
axes.set_xlabel('x axis')
axes.set_ylabel('y axis')
axes.set_title('object')
# Out:
# Text(0.5, 1.0, 'object')

# %%
# create a empty canvas
fig = plt.figure()

# add set of axes to figure
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# axes1
axes1.plot(x,y,'b')
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
axes1.set_title('object')

# axes2
axes2.plot(y,x,'g')
axes2.set_xlabel('x axis')
axes2.set_ylabel('y axis')
axes2.set_title('object2')
# Out:
# Text(0.5, 1.0, 'object2')

# %%
# tuple unpacking
fig,axes = plt.subplots()
axes.plot(x,y,'g')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
    ax.plot(x,y,'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

fig

# %%
for ax in axes:
    ax.plot(x,y,'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# %%
plt.tight_layout()

# %%
fig

# %%
fig = plt.figure(figsize =(8,4),dpi=100)

# %%
fig,axes= plt.subplots(figsize =(10,3))
axes.plot(x,y,'g--')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('figuree')
# Out:
# Text(0.5, 1.0, 'figuree')

# %%
fig.savefig('figuree.png')

# %%
# legends 

fig,axes= plt.subplots(figsize =(10,3))
axes.plot(x,y,'g--',label = 'xy')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('figuree')
axes.legend(loc = 0)

# %%
# MATLAB style line color and style 
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %%
fig, ax = plt.subplots()
ax.plot(x , x+1, 'b.-',alpha =0.5)
ax.plot(x , x+2, 'g--')
ax.plot(x , x+3, 'r',alpha =0.5,marker = '*',markersize = 8)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");
